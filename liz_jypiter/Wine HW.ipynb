# %% [markdown]
# # Homework Assignment 1

# %% [markdown]
# _Due by 10-FEB-2020_

# %% [markdown]
# The data for this homework assignment is sourced from the UCI Machine Learning Repository. This [link](https://archive.ics.uci.edu/ml/datasets/Wine+Quality) includes a brief description of all columns (features) available this dataset. You can download this data set from BlackBoard under the Data folder to your local computer and then read those files into Python.
#
# Answer the following questions based on this dataset. Submit a Jupyter Notebook that contains all your code that you used to answer these questions. You can post your submission via BlackBoard or email (patelvj2@vcu.edu). The Jupyter Notebook must be fully executable with no/minimal changes (such as the location of the input file).

# %%
import pandas
import os
os.chdir('/Users/liz/Documents/DAPT/Data_Mining')

df = pandas.read_csv('winequality.csv',encoding="ISO-8859-1")
df = df.drop(df.columns[0],axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %% [markdown]
# #### 1. Plot histograms for all variables in this data set. Add a vertical line to show the average value of each variable. Add a chart title for each chart.

# %%
import matplotlib.pyplot as pyp 
import seaborn as sns

# %%
num_cols = df.columns[0:12]
num_cols
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
for i in df.columns[0:12]:
    df[i].hist(bins=10)
    pyp.axvline(df[i].mean(), color='k', linestyle='dashed', linewidth=1)
    pyp.xlabel(i)
    pyp.show()

# %% [markdown]
# #### 2. Identify two features that are most correlated with each other. Visualize their relationship using an appropriate chart type.

# %%
cmap = sns.diverging_palette(10, 220, n=20)
sns.heatmap(df.corr(),cmap=cmap)

pyp.show()
pyp.close();

# %%
cmap = sns.diverging_palette(10, 220, n=20)
sns.clustermap(df.corr(),cmap=cmap)

pyp.show()
pyp.close();

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.plot.scatter(x='free sulfur dioxide',y='total sulfur dioxide')
df.plot.scatter(x='alcohol',y='density')

# %% [markdown]
# #### 3. Identify the feature that is most correlated with the wine quality and plot their relationship using an appropriate chart type.

# %%
df.plot.scatter(x='quality',y='alcohol')

# %% [markdown]
# #### 4. Calcluate average alcohol content for each wine quality score. Store the average alcohol content for the best quality wine in a variable called `avg_alcohol_for_best_wine` and print it using the following statement:
#
# `print(f'The average alcohol content for best wine is {avg_alcohol_for_best_wine}.')`

# %%
df.groupby('quality')['alcohol'].mean()
# Out:
# quality
# 3    10.215000
# 4    10.180093
# 5     9.837783
# 6    10.587553
# 7    11.386006
# 8    11.678756
# 9    12.180000
# Name: alcohol, dtype: float64

# %%
dfa=df[(df.quality==df.quality.max())]
best=dfa['alcohol'].mean()

# %%
print(f'The average alcohol content for best wine is {best}.')
# Out:
# The average alcohol content for best wine is 12.18.

# %% [markdown]
# #### 5. Calculate correlation coefficients between wine quality and all other features _separately for each wine type_. Identify any one feature that has contradictory relationships across the wine type. (For example, a feature has positive correlation with the wine quality for red wines, and negative correlation coefficients with the wine quality of white wines.) Plot the relationship of the selected feature with wine quality using an appropriate chart type.

# %%
df.groupby('wine type').corr()
#Red wine has a slightly positive correlation between fixed acidity and quality, 
#whereas white wine has a slightly negative correlation between the same variables.
# Out:
#                                 fixed acidity  volatile acidity  citric acid  \
# wine type
# Red       fixed acidity              1.000000         -0.256131     0.671703
#           volatile acidity          -0.256131          1.000000    -0.552496
#           citric acid                0.671703         -0.552496     1.000000
#           residual sugar             0.114777          0.001918     0.143577
#           chlorides                  0.093705          0.061298     0.203823
#           free sulfur dioxide       -0.153794         -0.010504    -0.060978
#           total sulfur dioxide      -0.113181          0.076470     0.035533
#           density                    0.668047          0.022026     0.364947
#           pH                        -0.682978          0.234937    -0.541904
#           sulphates                  0.183006         -0.260987     0.312770
#           alcohol                   -0.061668         -0.202288     0.109903
# ...

# %%
df[(df.wine_type=='Red')].plot.scatter(x='quality',y='fixed acidity',)
pyp.title('Red')

df[(df.wine_type=='White')].plot.scatter(x='quality',y='fixed acidity',)
pyp.title('White')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e21f8ea2f5c6> in <module>
# ----> 1 df[(df.wine_type=='Red')].plot.scatter(x='quality',y='fixed acidity',)
#       2 pyp.title('Red')
#       3
#       4 df[(df.wine_type=='White')].plot.scatter(x='quality',y='fixed acidity',)
#       5 pyp.title('White')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'wine_type'
